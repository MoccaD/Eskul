# %% [markdown]
# <a href="https://colab.research.google.com/github/MoccaD/Eskul/blob/main/Halo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hellow World")
# Out:
# Hellow World
